# %%
import numpy as np
import pandas as pd
import seaborn as sns
import acquire

import matplotlib.pyplot as plt

# import splitting and imputing functions
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# turn off pink boxes for demo
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ```python
# # Dummie variables
#     is_male=[1,0]
# ```

# %%
df=acquire.get_titanic_data()

# %%
dummies = pd.get_dummies(df[['sex', 'embark_town']],drop_first=True)

# %%
pd.concat([df,dummies],axis=1)
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone  sex_male  \
# ...

# %%
df['embark_town'].fillna('Southampton', inplace=True)

# %% [markdown]
# ### 1. Drop
# ### 2. Fill Blanks
# ### 3. Dummies
# ### 4. Concat

# %% [markdown]
# # Split Data

# %%
seed = 42

train,val_test = train_test_split(df, train_size=0.7, random_state=seed, stratify=df['survived'])

# %%
seed = 42

validate,test=train_test_split(val_test, train_size=0.7, random_state=seed, stratify=val_test['survived'])

# %%
train.shape, test.shape
# Out:
# ((623, 13), (268, 13))

# %%
def train_val_test(df):
    seed = 42
    train,val_test = train_test_split(df, train_size=0.7, random_state=seed, stratify=df['survived'])
    validate,test=train_test_split(val_test, train_size=0.7, random_state=seed, stratify=val_test['survived'])

# %% [markdown]
# # Impute

# %%
imputer = SimpleImputer()

# %%
impute_df = acquire.get_titanic_data()
impute_df
# Out:
#      Unnamed: 0  passenger_id  survived  pclass     sex   age  sibsp  parch  \
# 0             0             0         0       3    male  22.0      1      0
# 1             1             1         1       1  female  38.0      1      0
# 2             2             2         1       3  female  26.0      0      0
# 3             3             3         1       1  female  35.0      1      0
# 4             4             4         0       3    male  35.0      0      0
# ..          ...           ...       ...     ...     ...   ...    ...    ...
# 886         886           886         0       2    male  27.0      0      0
# 887         887           887         1       1  female  19.0      0      0
# 888         888           888         0       3  female   NaN      1      2
# 889         889           889         1       1    male  26.0      0      0
# 890         890           890         0       3    male  32.0      0      0
#
#         fare embarked   class deck  embark_town  alone
# ...

# %%
train,validate,test=train_val_test(impute_df)
train.shape
imputer.fit(train[['embark']],strategy='most_frequent')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 train,validate,test=train_val_test(impute_df)
#       2 train.shape
#       3 imputer.fit(train[['embark']],strategy='most_frequent')
#
# NameError: name 'train_val_test' is not defined

# %%
train['embark_town'] = imputer.transform(train[['embark_town']])

# %%
train['embark_town'].isna().sum()
